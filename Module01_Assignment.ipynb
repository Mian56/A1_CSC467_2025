# %% [markdown]
# # Module 01 Assignment: introduction to python programing
# ## task 1: print "Hello, World!"

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
from skimage import io as io_url

# %%
# Part 1: Plot a Simple Quadratic Equation
import matplotlib.pyplot as plt
import numpy as np

# Generate x values
x = np.linspace(-10, 10, 100)

# Quadratic equation: y = x^2 - 4x + 5
y = x**2 - 4*x + 5

# Plotting the graph
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = x^2 - 4x + 5', color='blue')
plt.title('Quadratic Equation Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %%
# Part 2: Plot an Image
import cv2
import numpy as np
from mpl_toolkits import mplot3d
from skimage import io as io_url

# Load the image file (update the path to your image)
frame = io_url.imread('https://upload.wikimedia.org/wikipedia/commons/3/3a/Cat03.jpg')
frame = np.float32(frame) / 255

plt.imshow(frame)
